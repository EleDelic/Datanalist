# %% [markdown]
# <a href="https://colab.research.google.com/github/EleDelic/Datanalist/blob/Elemento-de-colab/Exploratorio_De_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importamos las librerias necesarias:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Insertamos la conexion con el archivo de R
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_excel("/content/drive/My Drive/mtcars.xlsx")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ANALISIS PARA LAS VARIABLES NOMINALES (PORCENTAJE DE CARROS Y SU CILINDRAJE)

# %%
cilind=list(set(df['cyl']))
totales=[]
for i in cilind:
  totales.append(list(df['cyl']).count(i))
  
#CREACION DEL DF
res1 = pd.DataFrame()
res1['cyl'] = cilind
res1['cantidad']=totales
res1= res1.sort_values('cantidad',ascending=False)

#RESPUESTA
print("Los carros que existen tienen", len(cilind)," distinta cantidad de cilindros")
print("Cada una con los siguientes registros")
print(res1)


colors = ['c', 'g', 'y']

plt.pie(res1['cantidad'], labels=res1['cyl'], colors=colors,
        startangle=90,
        explode = (0, 0.05, 0),
        autopct = '%1.2f%%')

plt.axis('equal') # 
plt.title('Cantidad de carros con cilindros')
plt.show()
# Out:
# Los carros que existen tienen 3  distinta cantidad de cilindros
# Cada una con los siguientes registros
#    cyl  cantidad
# 0    8        14
# 1    4        11
# 2    6         7

# %% [markdown]
#   FORMA V DEL MOTOR

# %%
cilind=list(set(df['vs']))
totales=[]
for i in cilind:
  totales.append(list(df['vs']).count(i))
  
#CREACION DEL DF
res1 = pd.DataFrame()
res1['vs'] = cilind
res1['cantidad']=totales
res1= res1.sort_values('cantidad',ascending=False)

#RESPUESTA
print("Los carros que existen tienen", len(cilind)," distinta forma del motor")
print("Cada una con los siguientes registros")
print(res1)


colors = ['r', 'g']

plt.pie(res1['cantidad'], labels=res1['vs'], colors=colors,
        startangle=90,
        explode = (0, 0.05),
        autopct = '%1.2f%%')

plt.axis('equal') # 
plt.title('Cantidad de carros con cilindros')
plt.show()
# Out:
# Los carros que existen tienen 2  distinta cantidad de cilindros
# Cada una con los siguientes registros
#    vs  cantidad
# 0   0        18
# 1   1        14

# %% [markdown]
# Millas por galon

# %%
print("Los valores principales que nos brinda la información de millas por galón son:")
print(df['mpg'].describe())



plt.hist(df['mpg'], bins=20)
plt.title("Histograma")
plt.show()



def diagrama_caja_notas(notas):
    fig, ax = plt.subplots()
    notas.plot(kind = 'box', ax = ax)
    plt.xticks([])
    plt.title('Distribución')
    return ax

notas = df['mpg']
s_notas = pd.Series(notas)
diagrama_caja_notas(s_notas)
plt.show()
# Out:
# Los valores principales que nos brinda la información de millas por galón son:
# count    32.000000
# mean     20.090625
# std       6.026948
# min      10.400000
# 25%      15.425000
# 50%      19.200000
# 75%      22.800000
# max      33.900000
# Name: mpg, dtype: float64

# %% [markdown]
# Caballos de fuerza

# %%
print("Los valores principales que nos brinda la información de caballos de fuerza:")
print(df['hp'].describe())



plt.hist(df['hp'], bins=20)
plt.title("Histograma")
plt.show()



def diagrama_caja_notas(notas):
    fig, ax = plt.subplots()
    notas.plot(kind = 'box', ax = ax)
    plt.xticks([])
    plt.title('Distribución')
    return ax

notas = df['hp']
s_notas = pd.Series(notas)
diagrama_caja_notas(s_notas)
plt.show()
# Out:
# Los valores principales que nos brinda la información de caballos de fuerza:
# count     32.000000
# mean     146.687500
# std       68.562868
# min       52.000000
# 25%       96.500000
# 50%      123.000000
# 75%      180.000000
# max      335.000000
# Name: hp, dtype: float64

# %% [markdown]
# cuato de milla por segundo

# %%
print("Los valores principales que nos brinda la información de cuarto de millas por segundo son:")
print(df['qsec'].describe())



plt.hist(df['qsec'], bins=20)
plt.title("Histograma")
plt.show()



def diagrama_caja_notas(notas):
    fig, ax = plt.subplots()
    notas.plot(kind = 'box', ax = ax)
    plt.xticks([])
    plt.title('Distribución')
    return ax

notas = df['qsec']
s_notas = pd.Series(notas)
diagrama_caja_notas(s_notas)
plt.show()
# Out:
# Los valores principales que nos brinda la información de cuarto de millas por segundo son:
# count    32.000000
# mean     17.848750
# std       1.786943
# min      14.500000
# 25%      16.892500
# 50%      17.710000
# 75%      18.900000
# max      22.900000
# Name: qsec, dtype: float64

# %%
 plt.scatter(df['cyl'],df['mpg'], alpha=0.25)
 plt.title('Gráfio de dispersión cyl  and mpg')
 plt.show()

 plt.scatter(df['cyl'],df['hp'], alpha=0.25)
 plt.title('Gráfio de dispersión cyl  and hp')
 plt.show()

 plt.scatter(df['vs'],df['hp'], alpha=0.25)
 plt.title('Gráfio de dispersión vs  and hp')
 plt.show()

 plt.scatter(df['mpg'],df['hp'], alpha=0.25)
 plt.title('Gráfio de dispersión mpg  and hp')
 plt.show()
